# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv("../data/train.csv")
train_data.sample(5)
# Out:
#                    id              Gender        Age  HasDrivingLicense  \
# 105828      -0.082284   2.590575826361717  -2.781112          -1.356843
# 83765   100433.000000              Female  61.000000           1.000000
# 98850    45757.000000              Female  46.000000                NaN
# 104735       7.769928  0.4668584647041466  -0.191786           4.251765
# 37848   362805.000000              Female  24.000000           1.000000
#
#          RegionID    Switch          VehicleAge        PastAccident  \
# 105828  -0.392435 -0.536109  1.7855761604070617  -4.455810649121419
# 83765   35.000000       NaN            1-2 Year                 Yes
# 98850   39.000000       NaN            1-2 Year                 Yes
# 104735  -4.117691 -3.947819  2.2190258984799787  1.3994402731387812
# 37848         NaN  1.000000            < 1 Year                  No
#
#               AnnualPremium  SalesChannelID  DaysSinceCreated  Result
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108000 entries, 0 to 107999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 108000 non-null  float64
#  1   Gender             97883 non-null   object
#  2   Age                97909 non-null   float64
#  3   HasDrivingLicense  97997 non-null   float64
#  4   RegionID           98032 non-null   float64
#  5   Switch             57870 non-null   float64
#  6   VehicleAge         98185 non-null   object
#  7   PastAccident       57989 non-null   object
#  8   AnnualPremium      108000 non-null  object
#  9   SalesChannelID     108000 non-null  float64
#  10  DaysSinceCreated   108000 non-null  int64
#  11  Result             100000 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.9+ MB

# %%
train_data.isnull().sum()
# Out:
# id                       0
# Gender               10117
# Age                  10091
# HasDrivingLicense    10003
# RegionID              9968
# Switch               50130
# VehicleAge            9815
# PastAccident         50011
# AnnualPremium            0
# SalesChannelID           0
# DaysSinceCreated         0
# Result                8000
# dtype: int64

# %%
train_data['Result'].value_counts()
# Out:
# Result
# 0.0    87927
# 1.0    12073
# Name: count, dtype: int64

# %%
train_data = train_data[train_data['Result'].isnull()!=True]
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 100000 non-null  float64
#  1   Gender             89883 non-null   object
#  2   Age                89909 non-null   float64
#  3   HasDrivingLicense  89997 non-null   float64
#  4   RegionID           90032 non-null   float64
#  5   Switch             49870 non-null   float64
#  6   VehicleAge         90185 non-null   object
#  7   PastAccident       49989 non-null   object
#  8   AnnualPremium      100000 non-null  object
#  9   SalesChannelID     100000 non-null  float64
#  10  DaysSinceCreated   100000 non-null  int64
#  11  Result             100000 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.9+ MB

# %%
test_data = pd.read_csv("../data/test.csv")
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102000 entries, 0 to 101999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 102000 non-null  float64
#  1   Gender             92091 non-null   object
#  2   Age                92017 non-null   float64
#  3   HasDrivingLicense  92009 non-null   float64
#  4   RegionID           91903 non-null   float64
#  5   Switch             52305 non-null   float64
#  6   VehicleAge         91968 non-null   object
#  7   PastAccident       51687 non-null   object
#  8   AnnualPremium      102000 non-null  object
#  9   SalesChannelID     102000 non-null  float64
#  10  DaysSinceCreated   102000 non-null  int64
#  11  Result             100000 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.3+ MB

# %%
test_data.isnull().sum()
# Out:
# id                       0
# Gender                9909
# Age                   9983
# HasDrivingLicense     9991
# RegionID             10097
# Switch               49695
# VehicleAge           10032
# PastAccident         50313
# AnnualPremium            0
# SalesChannelID           0
# DaysSinceCreated         0
# Result                2000
# dtype: int64

# %%
test_data = test_data[test_data['Result'].isnull()!=True]
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 100000 non-null  float64
#  1   Gender             90091 non-null   object
#  2   Age                90017 non-null   float64
#  3   HasDrivingLicense  90009 non-null   float64
#  4   RegionID           89903 non-null   float64
#  5   Switch             50305 non-null   float64
#  6   VehicleAge         89968 non-null   object
#  7   PastAccident       49687 non-null   object
#  8   AnnualPremium      100000 non-null  object
#  9   SalesChannelID     100000 non-null  float64
#  10  DaysSinceCreated   100000 non-null  int64
#  11  Result             100000 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 9.9+ MB
